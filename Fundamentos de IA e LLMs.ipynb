# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
df = pd.read_csv("Churn_treino.csv", sep=";")
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure   Balance  NumOfProducts  \
# 0             619    France  Female   42       2         0              1
# 1             608     Spain  Female   41       1   8380786              1
# 2             502    France  Female   42       8   1596608              3
# 3             699    France  Female   39       1         0              2
# 4             850     Spain  Female   43       2  12551082              1
# ...           ...       ...     ...  ...     ...       ...            ...
# 9995          771    France    Male   39       5         0              2
# 9996          516    France    Male   35      10   5736961              1
# 9997          709    France  Female   36       7         0              1
# 9998          772   Germany    Male   42       3   7507531              2
# 9999          792    France  Female   28       4  13014279              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1         10134888       1
# 1             0               1         11254258       0
# 2             1               0         11393157       1
# 3             0               0          9382663       0
# 4             1               1           790841       0
# ...         ...             ...              ...     ...
# 9995          1               0          9627064       0
# 9996          1               1         10169977       0
# 9997          0               1          4208558       1
# 9998          1               0          9288852       1
# 9999          1               0          3819078       0
#
# [10000 rows x 11 columns]

# %%
X = df.drop("Exited", axis=1)
y = df["Exited"]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure   Balance  NumOfProducts  \
# 0             619    France  Female   42       2         0              1
# 1             608     Spain  Female   41       1   8380786              1
# 2             502    France  Female   42       8   1596608              3
# 3             699    France  Female   39       1         0              2
# 4             850     Spain  Female   43       2  12551082              1
# ...           ...       ...     ...  ...     ...       ...            ...
# 9995          771    France    Male   39       5         0              2
# 9996          516    France    Male   35      10   5736961              1
# 9997          709    France  Female   36       7         0              1
# 9998          772   Germany    Male   42       3   7507531              2
# 9999          792    France  Female   28       4  13014279              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1         10134888
# 1             0               1         11254258
# 2             1               0         11393157
# 3             0               0          9382663
# 4             1               1           790841
# ...         ...             ...              ...
# 9995          1               0          9627064
# 9996          1               1         10169977
# 9997          0               1          4208558
# 9998          1               0          9288852
# 9999          1               0          3819078
#
# [10000 rows x 10 columns]

# %%
standarscaler = StandardScaler()
numerical = X.select_dtypes(include=['int64','float64']).columns
X[numerical] = standarscaler.fit_transform(X[numerical])

# %%
X
# Out:
#       CreditScore Geography  Gender       Age    Tenure   Balance  \
# 0       -0.326221    France  Female  0.293517 -1.041760 -1.110553
# 1       -0.440036     Spain  Female  0.198164 -1.387538  0.222782
# 2       -1.536794    France  Female  0.293517  1.032908 -0.856542
# 3        0.501521    France  Female  0.007457 -1.387538 -1.110553
# 4        2.063884     Spain  Female  0.388871 -1.041760  0.886252
# ...           ...       ...     ...       ...       ...       ...
# 9995     1.246488    France    Male  0.007457 -0.004426 -1.110553
# 9996    -1.391939    France    Male -0.373958  1.724464 -0.197835
# 9997     0.604988    France  Female -0.278604  0.687130 -1.110553
# 9998     1.256835   Germany    Male  0.293517 -0.695982  0.083852
# 9999     1.463771    France  Female -1.041433 -0.350204  0.959944
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0         -0.911583   0.646092        0.970243         0.170614
# 1         -0.911583  -1.547768        0.970243         0.353281
# 2          2.527057   0.646092       -1.030670         0.375948
# 3          0.807737  -1.547768       -1.030670         0.047859
# 4         -0.911583   0.646092        0.970243        -1.354223
# ...             ...        ...             ...              ...
# 9995       0.807737   0.646092       -1.030670         0.087743
# 9996      -0.911583   0.646092        0.970243         0.176340
# 9997      -0.911583  -1.547768        0.970243        -0.796492
# 9998       0.807737   0.646092       -1.030670         0.032551
# 9999      -0.911583   0.646092       -1.030670        -0.860051
#
# [10000 rows x 10 columns]

# %%
labelencoder = LabelEncoder()
categorical = X.select_dtypes(include='object').columns
for col in categorical:
  X[col] = labelencoder.fit_transform(X[col])

# %%
X
# Out:
#       CreditScore  Geography  Gender       Age    Tenure   Balance  \
# 0       -0.326221          0       0  0.293517 -1.041760 -1.110553
# 1       -0.440036          2       0  0.198164 -1.387538  0.222782
# 2       -1.536794          0       0  0.293517  1.032908 -0.856542
# 3        0.501521          0       0  0.007457 -1.387538 -1.110553
# 4        2.063884          2       0  0.388871 -1.041760  0.886252
# ...           ...        ...     ...       ...       ...       ...
# 9995     1.246488          0       1  0.007457 -0.004426 -1.110553
# 9996    -1.391939          0       1 -0.373958  1.724464 -0.197835
# 9997     0.604988          0       0 -0.278604  0.687130 -1.110553
# 9998     1.256835          1       1  0.293517 -0.695982  0.083852
# 9999     1.463771          0       0 -1.041433 -0.350204  0.959944
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0         -0.911583   0.646092        0.970243         0.170614
# 1         -0.911583  -1.547768        0.970243         0.353281
# 2          2.527057   0.646092       -1.030670         0.375948
# 3          0.807737  -1.547768       -1.030670         0.047859
# 4         -0.911583   0.646092        0.970243        -1.354223
# ...             ...        ...             ...              ...
# 9995       0.807737   0.646092       -1.030670         0.087743
# 9996      -0.911583   0.646092        0.970243         0.176340
# 9997      -0.911583  -1.547768        0.970243        -0.796492
# 9998       0.807737   0.646092       -1.030670         0.032551
# 9999      -0.911583   0.646092       -1.030670        -0.860051
#
# [10000 rows x 10 columns]

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
modelo = Sequential()
modelo.add(Dense(units=64, activation='relu', input_dim=X_treino.shape[1]))
modelo.add(Dropout(0.4))
modelo.add(Dense(units=32, activation='relu'))
modelo.add(Dropout(0.4))
modelo.add(Dense(units=64, activation='relu'))
modelo.add(Dropout(0.4))
modelo.add(Dense(units=1, activation='sigmoid'))

# %%
modelo.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
modelo.fit(X_treino, y_treino, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 219/219 [==============================] - 5s 4ms/step - loss: 0.5122 - accuracy: 0.7889
# Epoch 2/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.4649 - accuracy: 0.7967
# Epoch 3/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.4519 - accuracy: 0.8001
# Epoch 4/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.4379 - accuracy: 0.8051
# Epoch 5/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.4294 - accuracy: 0.8131
# Epoch 6/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.4141 - accuracy: 0.8220
# Epoch 7/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.4061 - accuracy: 0.8283
# Epoch 8/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3987 - accuracy: 0.8326
# Epoch 9/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3941 - accuracy: 0.8337
# Epoch 10/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3926 - accuracy: 0.8357
# Epoch 11/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.3933 - accuracy: 0.8326
# Epoch 12/50
# 219/219 [==============================] - 1s 6ms/step - loss: 0.3883 - accuracy: 0.8419
# Epoch 13/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.3825 - accuracy: 0.8423
# Epoch 14/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3798 - accuracy: 0.8454
# Epoch 15/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3781 - accuracy: 0.8439
# Epoch 16/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3793 - accuracy: 0.8474
# Epoch 17/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3732 - accuracy: 0.8491
# Epoch 18/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3753 - accuracy: 0.8477
# Epoch 19/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3713 - accuracy: 0.8487
# Epoch 20/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3733 - accuracy: 0.8486
# Epoch 21/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3702 - accuracy: 0.8526
# Epoch 22/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3696 - accuracy: 0.8527
# Epoch 23/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3599 - accuracy: 0.8536
# Epoch 24/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3687 - accuracy: 0.8503
# Epoch 25/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3606 - accuracy: 0.8553
# Epoch 26/50
# 219/219 [==============================] - 1s 6ms/step - loss: 0.3679 - accuracy: 0.8529
# Epoch 27/50
# 219/219 [==============================] - 1s 6ms/step - loss: 0.3643 - accuracy: 0.8540
# Epoch 28/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3619 - accuracy: 0.8551
# Epoch 29/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3615 - accuracy: 0.8550
# Epoch 30/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3592 - accuracy: 0.8561
# Epoch 31/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3590 - accuracy: 0.8540
# Epoch 32/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3622 - accuracy: 0.8549
# Epoch 33/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3569 - accuracy: 0.8569
# Epoch 34/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3572 - accuracy: 0.8561
# Epoch 35/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3538 - accuracy: 0.8599
# Epoch 36/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3572 - accuracy: 0.8559
# Epoch 37/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3543 - accuracy: 0.8581
# Epoch 38/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3565 - accuracy: 0.8553
# Epoch 39/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3538 - accuracy: 0.8601
# Epoch 40/50
# 219/219 [==============================] - 1s 6ms/step - loss: 0.3574 - accuracy: 0.8566
# Epoch 41/50
# 219/219 [==============================] - 1s 6ms/step - loss: 0.3499 - accuracy: 0.8617
# Epoch 42/50
# 219/219 [==============================] - 1s 5ms/step - loss: 0.3497 - accuracy: 0.8611
# Epoch 43/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3584 - accuracy: 0.8557
# Epoch 44/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3532 - accuracy: 0.8593
# Epoch 45/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3564 - accuracy: 0.8596
# Epoch 46/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3484 - accuracy: 0.8604
# Epoch 47/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3536 - accuracy: 0.8587
# Epoch 48/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3519 - accuracy: 0.8597
# Epoch 49/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3504 - accuracy: 0.8563
# Epoch 50/50
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3524 - accuracy: 0.8581

# %%
previsoes = modelo.predict(X_teste)
previsoes
# Out:
# 94/94 [==============================] - 0s 2ms/step
# array([[0.31996924],
#        [0.26646012],
#        [0.22366658],
#        ...,
#        [0.06022881],
#        [0.1054535 ],
#        [0.61636335]], dtype=float32)

# %%
y_pred = (previsoes > 0.5).astype('int32')
y_pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]], dtype=int32)

# %%
print('Acurácia: ', accuracy_score(y_teste, y_pred))
print('F1: ', f1_score(y_teste, y_pred))
print('Recall: ', recall_score(y_teste, y_pred))
print('Matriz de Confusão: ', confusion_matrix(y_teste, y_pred))
# Out:
# Acurácia:  0.8626666666666667
# F1:  0.5992217898832685
# Recall:  0.49597423510466987
# Matriz de Confusão:  [[2280   99]
#  [ 313  308]]
